# %% [markdown]
# <a href="https://colab.research.google.com/github/Advaith9/Advaith9/blob/main/Assignment14_reading_gas_prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
filename = 'gasprices.txt'

line_number = 1
with open(filename) as gasprices_file_obj:
  for each_line in gasprices_file_obj:
#first splitting the date and price by ":"    
    elements = line.split(":")
    date, price = elements
#next splitting the date by the "-"    
    date_parts = date.split("-")
    month, day, year = date_parts
    print("Line number:", line_number)
    print("Month:", month)
    print("Day:", day)
    print("Year:", year)
    print("Price:", price)
    print("")
    line_number += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# Price: 3.623
#
# Line number: 233
# Month: 08
# Day: 26
# Year: 2013
# Price: 3.623
#
# Line number: 234
# Month: 08
# Day: 26
# Year: 2013
# Price: 3.623
#
# Line number: 235
# Month: 08
# Day: 26
# Year: 2013
# Price: 3.623
#
# Line number: 236
# Month: 08
# Day: 26
# Year: 2013
# Price: 3.623
#
# Line number: 237
# Month: 08
# Day: 26
# Year: 2013
# Price: 3.623
#
# Line number: 238
# Month: 08
# Day: 26
# Year: 2013
# Price: 3.623
#
# Line number: 239
# Month: 08
# Day: 26
# Year: 2013
# Price: 3.623
#
# Line number: 240
# Month: 08
# Day: 26
# Year: 2013
# Price: 3.623
#
# Line number: 241
# Month: 08
# Day: 26
# Year: 2013
# Price: 3.623
#
# Line number: 242
# Month: 08
# Day: 26
# Year: 2013
# Price: 3.623
#
# Line number: 243
# Month: 08
# Day: 26
# Year: 2013
# Price: 3.623
#
# Line number: 244
# Month: 08
# Day: 26
# Year: 2013
# Price: 3.623
#
# Line number: 245
# Month: 08
# Day: 26
# Year: 2013
# Price: 3.623
#
# ...
